# %%
import pandas as pd

# %%
glaxo=pd.read_csv("D:\\data science\\Priyanka DS\\GLAXO.csv")
glaxo
# Out:
#             Date     Open     High      Low    Last    Close  \
# 0     2010-01-04  1613.00  1629.10  1602.00  1629.0  1625.65
# 1     2010-01-05  1639.95  1639.95  1611.05  1620.0  1616.80
# 2     2010-01-06  1618.00  1644.00  1617.00  1639.0  1638.50
# 3     2010-01-07  1645.00  1654.00  1636.00  1648.0  1648.70
# 4     2010-01-08  1650.00  1650.00  1626.55  1640.0  1639.80
# ...          ...      ...      ...      ...     ...      ...
# 1734  2016-12-26  2703.00  2740.00  2677.00  2715.0  2723.50
# 1735  2016-12-27  2722.95  2725.00  2683.00  2692.0  2701.75
# 1736  2016-12-28  2701.75  2718.00  2690.00  2698.0  2702.15
# 1737  2016-12-29  2702.05  2739.00  2691.95  2710.0  2727.90
# 1738  2016-12-30  2730.00  2740.45  2705.00  2730.0  2729.80
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                   9365.0           151.74
# 1                  38148.0           622.58
# 2                  36519.0           595.09
# 3                  12809.0           211.00
# ...

# %%
beml=pd.read_csv("D:\\data science\\Priyanka DS\\BEML.csv")
beml
# Out:
#             Date     Open     High      Low     Last    Close  \
# 0     2010-01-04  1121.00  1151.00  1121.00  1134.00  1135.60
# 1     2010-01-05  1146.80  1149.00  1128.75  1135.00  1134.60
# 2     2010-01-06  1140.00  1164.25  1130.05  1137.00  1139.60
# 3     2010-01-07  1142.00  1159.40  1119.20  1141.00  1144.15
# 4     2010-01-08  1156.00  1172.00  1140.00  1141.20  1144.05
# ...          ...      ...      ...      ...      ...      ...
# 1734  2016-12-26   965.00   965.05   935.00   950.10   950.25
# 1735  2016-12-27   960.70   989.00   952.35   974.00   975.70
# 1736  2016-12-28   980.75   985.00   970.15   977.00   974.40
# 1737  2016-12-29   977.10   997.95   974.55   985.15   986.05
# 1738  2016-12-30   986.00  1006.95   985.90  1004.00  1000.60
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                 101651.0          1157.18
# 1                  59504.0           676.47
# 2                 128908.0          1482.84
# ...

# %%
glaxo_df=glaxo[['Date','Close']]
beml_df=beml[['Date','Close']]

# %%
glaxo_df
# Out:
#             Date    Close
# 0     2010-01-04  1625.65
# 1     2010-01-05  1616.80
# 2     2010-01-06  1638.50
# 3     2010-01-07  1648.70
# 4     2010-01-08  1639.80
# ...          ...      ...
# 1734  2016-12-26  2723.50
# 1735  2016-12-27  2701.75
# 1736  2016-12-28  2702.15
# 1737  2016-12-29  2727.90
# 1738  2016-12-30  2729.80
#
# [1739 rows x 2 columns]

# %%
beml_df
# Out:
#             Date    Close
# 0     2010-01-04  1135.60
# 1     2010-01-05  1134.60
# 2     2010-01-06  1139.60
# 3     2010-01-07  1144.15
# 4     2010-01-08  1144.05
# ...          ...      ...
# 1734  2016-12-26   950.25
# 1735  2016-12-27   975.70
# 1736  2016-12-28   974.40
# 1737  2016-12-29   986.05
# 1738  2016-12-30  1000.60
#
# [1739 rows x 2 columns]

# %%
glaxo_df['Date']=pd.to_datetime(glaxo_df['Date'])
beml_df['Date']=pd.to_datetime(beml_df['Date'])
# Out:
# C:\Users\madan\AppData\Local\Temp\ipykernel_15792\2104506189.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   glaxo_df['Date']=pd.to_datetime(glaxo_df['Date'])
# C:\Users\madan\AppData\Local\Temp\ipykernel_15792\2104506189.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beml_df['Date']=pd.to_datetime(beml_df['Date'])

# %%
glaxo_df.dtypes
# Out:
# Date     datetime64[ns]
# Close           float64
# dtype: object

# %%
beml_df.dtypes
# Out:
# Date     datetime64[ns]
# Close           float64
# dtype: object

# %%
glaxo_df=glaxo_df.set_index(pd.DatetimeIndex(glaxo_df['Date']))
beml_df=beml_df.set_index(pd.DatetimeIndex(beml_df['Date']))

# %%
glaxo_df.drop('Date',axis=1)
# Out:
#               Close
# Date
# 2010-01-04  1625.65
# 2010-01-05  1616.80
# 2010-01-06  1638.50
# 2010-01-07  1648.70
# 2010-01-08  1639.80
# ...             ...
# 2016-12-26  2723.50
# 2016-12-27  2701.75
# 2016-12-28  2702.15
# 2016-12-29  2727.90
# 2016-12-30  2729.80
#
# [1739 rows x 1 columns]

# %%
beml_df.drop('Date',axis=1)
# Out:
#               Close
# Date
# 2010-01-04  1135.60
# 2010-01-05  1134.60
# 2010-01-06  1139.60
# 2010-01-07  1144.15
# 2010-01-08  1144.05
# ...             ...
# 2016-12-26   950.25
# 2016-12-27   975.70
# 2016-12-28   974.40
# 2016-12-29   986.05
# 2016-12-30  1000.60
#
# [1739 rows x 1 columns]

# %%
glaxo_df['gain']=glaxo_df.Close.pct_change(periods=1)
beml_df['gain']=beml_df.Close.pct_change(periods=1)

# %%
glaxo_df.drop('Date',axis=1)
# Out:
#               Close      gain
# Date
# 2010-01-04  1625.65       NaN
# 2010-01-05  1616.80 -0.005444
# 2010-01-06  1638.50  0.013422
# 2010-01-07  1648.70  0.006225
# 2010-01-08  1639.80 -0.005398
# ...             ...       ...
# 2016-12-26  2723.50 -0.001283
# 2016-12-27  2701.75 -0.007986
# 2016-12-28  2702.15  0.000148
# 2016-12-29  2727.90  0.009529
# 2016-12-30  2729.80  0.000697
#
# [1739 rows x 2 columns]

# %%
beml_df.drop('Date',axis=1)
# Out:
#               Close      gain
# Date
# 2010-01-04  1135.60       NaN
# 2010-01-05  1134.60 -0.000881
# 2010-01-06  1139.60  0.004407
# 2010-01-07  1144.15  0.003993
# 2010-01-08  1144.05 -0.000087
# ...             ...       ...
# 2016-12-26   950.25 -0.021924
# 2016-12-27   975.70  0.026782
# 2016-12-28   974.40 -0.001332
# 2016-12-29   986.05  0.011956
# 2016-12-30  1000.60  0.014756
#
# [1739 rows x 2 columns]

# %%
glaxo_df.dropna()
beml_df.dropna()
# Out:
#                  Date    Close      gain
# Date
# 2010-01-05 2010-01-05  1134.60 -0.000881
# 2010-01-06 2010-01-06  1139.60  0.004407
# 2010-01-07 2010-01-07  1144.15  0.003993
# 2010-01-08 2010-01-08  1144.05 -0.000087
# 2010-01-11 2010-01-11  1137.00 -0.006162
# ...               ...      ...       ...
# 2016-12-26 2016-12-26   950.25 -0.021924
# 2016-12-27 2016-12-27   975.70  0.026782
# 2016-12-28 2016-12-28   974.40 -0.001332
# 2016-12-29 2016-12-29   986.05  0.011956
# 2016-12-30 2016-12-30  1000.60  0.014756
#
# [1738 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(10,6))
plt.plot(glaxo_df.gain)
plt.xlabel('Time')
plt.ylabel('Gain')
# Out:
# Text(0, 0.5, 'Gain')

# %%
fig=plt.figure(figsize=(10,6))
plt.plot(beml_df.gain)
plt.xlabel('Time')
plt.ylabel('Gain')
# Out:
# Text(0, 0.5, 'Gain')

# %%
import seaborn as sn

# %%
fig=plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
sn.distplot(glaxo_df.gain)
plt.xlabel('gain')
plt.ylabel('frequency')
plt.legend()
plt.subplot(1,2,2)
sn.distplot(beml_df.gain)
plt.xlabel('gain')
plt.ylabel('frequency')
plt.legend()
# Out:
# C:\Users\madan\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\madan\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
print('mean and std dev for galaxo',glaxo_df.gain.mean(),glaxo_df.gain.std())
print('mean and std dev for beml',beml_df.gain.mean(),beml_df.gain.std())
# Out:
# mean and std dev for galaxo 0.0003860410825922916 0.013360538552253333
# mean and std dev for beml 0.00027074807905723154 0.02643083146847487

# %%
from scipy import stats
#find probability for 2% loss or higher for glaxo and beml
print('probability of glaxo for 2%loss',stats.norm.cdf(-0.02,0.000386,0.0133605))
print('probability of beml for 2%loss',stats.norm.cdf(-0.02,0.00027074,0.02643083))
# Out:
# probability of glaxo for 2%loss 0.06352472127411887
# probability of beml for 2%loss 0.22155995324301664

# %%
#find probability for 2% gain or higher for glaxo and beml
print('probability of glaxo for 2%gain',1-stats.norm.cdf(0.02,0.000386,0.0133605))
print('probability of beml for 2%gain',1-stats.norm.cdf(0.02,0.00027074,0.02643083))
# Out:
# probability of glaxo for 2%loss 0.07104412169532348
# probability of beml for 2%loss 0.22769819002575842
